# %%
import cv2
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Zadanie 1

# %%
nazwapliku = 'facebook_cover.jpg'

# otwarcie obrazka
obrazek = cv2.imread(nazwapliku)

# ile wierszy, kolumn i kanałów ma wczytany obrazek?
print(obrazek.shape)

# pokazanie obrazka
cv2.imshow('Kitku', obrazek)

# oczekiwanie na przycisniecie dowolnego klawisza - abyśmy zdążyli obejrzeć obrazek
cv2.waitKey()

# zamknięcie okienka
cv2.destroyAllWindows()
print(obrazek.shape)

# %%
plt.imshow(obrazek[0:630, 0:1200])

# %%
obrazek.shape

# %%
# Wczytaj obraz
img = cv2.imread(r'/home/vboxuser/Python/facebook_cover.jpg')

# Sprawdź, czy obraz został załadowany
if img is None:
    print("Błąd: Obraz nie został wczytany. Sprawdź ścieżkę do pliku.")
else:
    # Konwertowanie obrazu z BGR na RGB (OpenCV używa BGR, matplotlib wymaga RGB)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Wyświetlenie obrazu
    plt.imshow(img_rgb)
    plt.axis('off')  # Ukrywa osie
    plt.show()

# %% [markdown]
# Zadanie 2

# %%
from PIL import Image
imgPIL = Image.open('/home/vboxuser/Python/facebook_cover.jpg')
imgPIL.show()

# %%
## Wyświetlanie z matplotlib
plt.imshow(imgPIL)
plt.axis('off')  # Ukrywa osie
plt.show()

# %%
## Wyświetlanie z OpenCV
import numpy as np
imgPIL_np = np.array(imgPIL)

# Konwersja z RGB (PIL) na BGR (OpenCV)
imgPIL_bgr = cv2.cvtColor(imgPIL_np, cv2.COLOR_RGB2BGR)
#imgPIL_bgr = cv2.cvtColor(imgPIL, cv2.COLOR_RGB2BGR) [err]
#bez konwersji na tablice np nie zadziałało

# Wyświetlenie obrazu za pomocą OpenCV
cv2.imshow("Obraz", imgPIL_bgr)
cv2.waitKey(0)  # Oczekiwanie na dowolny klawisz
cv2.destroyAllWindows()  # Zamknięcie okna

# %%
nazwapliku = 'facebook_cover.jpg'

obrazek = cv2.imread(nazwapliku)

# wybranie wszystkich kanałów
# ale tylko 50 wierszy i 100 kolumn z obrazka
fragment_obrazka = obrazek[0:630, 500:800, :]

# pokazanie obrazka
cv2.imshow('fragment obrazka', fragment_obrazka)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# Zadanie 3

# %%
import numpy as np
import cv2

# %%
cap3 = cv2.VideoCapture(0)
if not cap3.isOpened():
    print("Cannot open camera")
    exit()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
 
'''
 cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

'''

# obiekt capture będzie wskazywał kamerę podłączoną do komputera 
capture = cv2.VideoCapture(0)

# zdefiniowanie kodeka
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# utworzenie obiektu do nagrywania filmu
film = cv2.VideoWriter('output.avi', fourcc, 20.0, (640,  480))

while capture.isOpened():
    # z otwartego wcześniej źródła spróbujemy wczytać kolejną klatkę obrazu
    ret,image = capture.read()

    image[:,:,2] = cv2.add(image[:,:,1],35)
    
    # jeśli udało się wczytać kolejną klatkę obrazu
    # wyświetlimy ją na w osobnym oknie - tak jak wcześniej wyświetlaliśmy zwykły obraz
    if ret == True:
        film.write(image)
        cv2.imshow('Obraz z kamery', image)

        # przerwij wykonywanie programu po nacisnieciu klaswisza 'x'
        if cv2.waitKey(25) & 0xFF == ord('x'):
            obraz = cv2.imwrite('obrazek.jpg',image)
            break
            
            
    # zakończenie pętli gdy nie udało się wczytać następnej klatki z kamery
    else: 
         break

# ważne aby zwolnić dostęp do filmu i do kamery
film.release()
capture.release()

# warto również zamknąć okna które zostały otwarte podczas wykonywania programu
cv2.destroyAllWindows()

# %%
from PIL import Image
foto = Image.open('obrazek.jpg')

plt.imshow(foto)
plt.axis('off')  # Ukrywa osie
plt.show()

# %% [markdown]
# Zadanie 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

nazwapliku = 'glass.jpg'
# załadowanie klasyfikatorów
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# otwarcie obrazka
obrazek = cv2.imread(nazwapliku)
szarosci = cv2.cvtColor(obrazek, cv2.COLOR_BGR2GRAY)

# wczytany obraz
plt.imshow(cv2.cvtColor(obrazek, cv2.COLOR_BGR2RGB))

# ile wierszy, kolumn i kanałów ma wczytany obrazek?
print(obrazek.shape)

# %% [markdown]
# Amongst these parameters, you need to pay more attention to four of them:
#
# scaleFactor – Parameter specifying how much the image size is reduced at each image scale.
# Basically, the scale factor is used to create your scale pyramid. More explanation, your model has a fixed size defined during training, which is visible in the XML. This means that this size of the face is detected in the image if present. However, by rescaling the input image, you can resize a larger face to a smaller one, making it detectable by the algorithm.
#
# 1.05 is a good possible value for this, which means you use a small step for resizing, i.e. reduce the size by 5%, you increase the chance of a matching size with the model for detection is found. This also means that the algorithm works slower since it is more thorough. You may increase it to as much as 1.4 for faster detection, with the risk of missing some faces altogether.
#
# minNeighbors – Parameter specifying how many neighbors each candidate rectangle should have to retain it.
# This parameter will affect the quality of the detected faces. Higher value results in fewer detections but with higher quality. 3~6 is a good value for it.
#
# minSize – Minimum possible object size. Objects smaller than that are ignored.
# This parameter determines how small size you want to detect. You decide it! Usually, [30, 30] is a good start for face detection.
#
# maxSize – Maximum possible object size. Objects bigger than this are ignored.
# This parameter determines how big size you want to detect. Again, you decide it! Usually, you don't need to set it manually, the default value assumes you want to detect without an upper limit on the size of the face.

# %%
faces = face_cascade.detectMultiScale(szarosci, 1.3, 5)
licznik = 0
oczy = 0
for (x,y,w,h) in faces:

    # wyyrysowanie odnalezionych twarzy      
    img = cv2.rectangle(obrazek,(x,y),(x+w,y+h),(255,0,0),2)
    licznik = licznik + 1
    
    # wybranie fragmentu obrazu z wykrytą twarzą
    roi_szarosci = szarosci[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    
    # wyszukanie oczu w obrębie wykrytej twarzy
    eyes = eye_cascade.detectMultiScale(roi_szarosci)
    
    # wyyrysowanie odnalezionych oczu      
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        oczy = oczy + 1

# wyświetlenie wynikowego obrazu      
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
print("Liczba twarzy: ", licznik)
print("Liczba oczu: ", oczy)

# %% [markdown]
# Zadanie 5

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

'''
 cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

'''

# obiekt capture będzie wskazywał kamerę podłączoną do komputera 
capture = cv2.VideoCapture(0)

# zdefiniowanie kodeka
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# utworzenie obiektu do nagrywania filmu
film = cv2.VideoWriter('output.avi', fourcc, 20.0, (640,  480))

while capture.isOpened():
    # z otwartego wcześniej źródła spróbujemy wczytać kolejną klatkę obrazu
    ret,image = capture.read()

    image[:,:,2] = cv2.add(image[:,:,1],35)
    
    # jeśli udało się wczytać kolejną klatkę obrazu
    # wyświetlimy ją na w osobnym oknie - tak jak wcześniej wyświetlaliśmy zwykły obraz
    if ret == True:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        
        # Wyświetlenie liczby wykrytych twarzy
        message = f"Liczba wykrytych twarzy: {len(faces)}"
        cv2.putText(image, message, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

        for (x,y,w,h) in faces:

            # wyyrysowanie odnalezionych twarzy      
            image = cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            film.write(image)
            cv2.imshow('Obraz z kamery', image)
            # wybranie fragmentu obrazu z wykrytą twarzą
            roi_szarosci = gray[y:y+h, x:x+w]
            roi_color = image[y:y+h, x:x+w]
    
            # wyszukanie oczu w obrębie wykrytej twarzy
            eyes = eye_cascade.detectMultiScale(roi_szarosci)



            for (ex,ey,ew,eh) in eyes:
                cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    
            
        # przerwij wykonywanie programu po nacisnieciu klaswisza 'x'
        if cv2.waitKey(25) & 0xFF == ord('x'):
            obraz = cv2.imwrite('obrazekTwarz.jpg',image)
            break
            
            
    # zakończenie pętli gdy nie udało się wczytać następnej klatki z kamery
    else: 
         break

# ważne aby zwolnić dostęp do filmu i do kamery
film.release()
capture.release()

# warto również zamknąć okna które zostały otwarte podczas wykonywania programu
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# QObject::moveToThread: Current thread (0xc1e41c0) is not the object's thread (0xccf4dd0).
# Cannot move to target thread (0xc1e41c0)
#
# ...
